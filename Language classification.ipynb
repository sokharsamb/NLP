# %%
import io, sys, math, re
from collections import defaultdict
import numpy as np

# %%
def load_data(filename):
    '''
    Parameters:
    filename (string): path to file to be read
    
    Return: 
    List of tuples (explained in first question)
    '''
    fin = io.open(filename, 'r', encoding='utf-8')
    data = []
    for line in fin:
        tokens = line.split()
        data.append((tokens[0], tokens[1:]))
    return data

# %%
data = load_data("train1.txt")
data
# Tuple
# Out:
# [('__label__deu',
#   ['Ich', 'würde', 'alles', 'tun,', 'um', 'dich', 'zu', 'beschützen.']),
#  ('__label__deu', ['Tom', 'ist', 'an', 'Kunst', 'völlig', 'uninteressiert.']),
#  ('__label__hun', ['Végeztem', 'Tomival.']),
#  ('__label__deu',
#   ['„Wird',
#    'das',
#    'in',
#    'der',
#    'Werkstatt',
#    'gemacht?“',
#    '–',
#    '„Nein,',
#    'das',
#    'muss',
#    'an',
#    'Ort',
#    'und',
#    'Stelle',
#    'erledigt',
#    'werden.“']),
#  ('__label__rus', ['У', 'меня', 'есть', 'яблоко.']),
#  ('__label__ita', ['Non', 'possiamo', 'lasciarle', 'lì.']),
#  ('__label__rus',
#   ['Том',
#    'считает,',
#    'что',
#    'школа',
#    '—',
#    'это',
#    'пустая',
#    'трата',
#    'времени.']),
#  ('__label__eng', ['My', 'fathers', "don't", 'speak', 'Dutch.']),
#  ('__label__spa', ['El', 'niño', 'no', 'sabe', 'cómo', 'comportarse.']),
#  ('__label__rus', ['Она', 'думала,', 'что', 'он', 'переночует', 'у', 'неё.']),
#  ('__label__tur', ['Helikopter', 'neden', 'kentin', 'üstünde', 'uçuyor?']),
#  ('__label__ita', ['Lo', 'prenda!', 'È', 'un', 'proiettile', 'magico.']),
#  ('__label__epo', ['Mi', 'volas', 'novan', 'poŝtelefonon!']),
#  ('__label__hun', ['Hagyj', 'engem', 'egyedül!']),
#  ('__label__spa', ['Hice', 'mi', 'trabajo.']),
#  ('__label__spa',
#   ['Me',
#    'costó',
#    'diez',
#    'mil',
#    'yenes',
#    'para',
#    'reparar',
#    'mi',
#    'televisión.']),
#  ('__label__eng', ['Tomorrow', 'is', 'the', 'election.']),
#  ('__label__por', ['Quando', 'está', 'frio', 'lá', 'fora,', 'uso', 'luvas.']),
#  ('__label__rus',
#   ['Том', 'говорит,', 'что', 'всю', 'жизнь', 'прожил', 'в', 'Австралии.']),
#  ('__label__tur', ['Bu', 'modeller', 'özdeş.']),
#  ('__label__epo',
#   ['Kompreneblas,', 'ke', 'la', 'idearo', 'estas', 'eksmoda.']),
#  ('__label__eng', ['You', "can't", 'help', 'but', 'like', 'him.']),
#  ('__label__fra',
#   ['Tout', 'le', 'monde', 'sait', 'que', 'tu', 'es', 'un', 'menteur.']),
#  ('__label__rus', ['Это', 'именно', 'то,', 'чего', 'я', 'хотел.']),
#  ('__label__ita', ['Siete', 'meravigliosi.']),
#  ('__label__eng', ['What', 'purpose', 'would', 'that', 'serve?']),
#  ('__label__eng', ['Someone', 'will', 'do', 'that', 'job.']),
#  ('__label__eng',
#   ['He',
#    'worked',
#    'hard',
#    'to',
#    'make',
#    'his',
#    'ideas',
#    'understandable',
#    'at',
#    'the',
#    'meeting.']),
#  ('__label__epo',
#   ['Estas',
#    'mi,',
#    'kiu',
#    'transdonis',
#    'la',
#    'donacon',
#    'okaze',
#    'de',
#    'ilia',
#    'naskiĝtago.']),
#  ('__label__por', ['Levantem', 'as', 'mãos', 'os', 'que', 'entenderam.']),
#  ('__label__fra', ['Elle', 'aime', 'se', 'promener', 'seule.']),
#  ('__label__hun', ['Tom', 'hányni', 'kezdett.']),
#  ('__label__eng',
#   ['Tom', 'asked', 'Mary', 'why', "she'd", 'been', 'arrested.']),
#  ('__label__tur', ['Ben', 'cehaleti', 'savunabilirim.']),
#  ('__label__eng', ["We'd", 'better', 'win.']),
#  ('__label__ita',
#   ['Tom', 'ha', 'portato', 'Mary', "all'ospedale", 'più', 'vicino.']),
#  ('__label__por', ['Qual', 'é', 'a', 'pressa?']),
#  ('__label__epo',
#   ['Mi',
#    'deziras',
#    'manĝi',
#    'rostitan',
#    'ŝafidaĵon',
#    'spicitan',
#    'per',
#    'rosmareno',
#    'kaj',
#    'krome',
#    'terpoman',
#    'kaĉon,',
#    'karotojn,',
#    'verdajn',
#    'fazeolojn',
#    'kaj',
#    'mentan',
#    'saŭcon.']),
#  ('__label__rus', ['Я', 'не', 'знала,', 'что', 'ты', 'помогаешь', 'Тому.']),
#  ('__label__epo', ['Ili', 'ne', 'havas', 'latvan', 'naciecon.']),
#  ('__label__deu', ['Jeder', 'liebt', 'Musik.']),
#  ('__label__rus', ['Я', 'не', 'ем', 'мясо', 'и', 'яйца.']),
#  ('__label__por',
#   ['Seja',
#    'bom',
#    'para',
#    'seus',
#    'flhos.',
#    'Um',
#    'dia',
#    'eles',
#    'vão',
#    'escolher',
#    'o',
#    'seu',
#    'asilo.']),
#  ('__label__eng', ['You', 'did', 'that', 'intentionally,', "didn't", 'you?']),
#  ('__label__por',
#   ['Então',
#    'os',
#    'fundadores',
#    'convocaram',
#    'a',
#    'Paris',
#    'uma',
#    'comissão',
#    'de',
#    'homens',
#    'de',
#    'ciência',
#    'de',
#    'diversos',
#    'países.',
#    'Três',
#    'ou',
#    'quatro',
#    '(Couturat,',
#    'Ostwald,',
#    'Jespersen,',
#    'Baudouin',
#    'de',
#    'Courtenay)',
#    'se',
#    'apresentaram.']),
#  ('__label__hun', ['Holnap', 'délelőttös', 'leszek.']),
#  ('__label__rus', ['Том', 'загадал', 'желание.']),
#  ('__label__ita', ['Mi', 'sa', 'che', 'devi', 'studiarla,', 'la', 'musica.']),
#  ('__label__epo', ['Adiaŭ,', 'bela', 'mondo!']),
#  ('__label__eng', ['I', 'want', 'to', 'stay', 'with', 'you.']),
#  ('__label__deu', ['Tom', 'ist', 'jetzt', 'dreißig.']),
#  ('__label__por', ['Sou', 'húngaro,', 'e', 'você?']),
#  ('__label__rus', ['Случай,', 'по', 'всей', 'видимости,', 'непростой.']),
#  ('__label__ita',
#   ['Prima', 'andate', 'voi', 'a', 'spalare', 'fango,', 'poi', 'parlate.']),
#  ('__label__spa',
#   ['Encontrarás', 'la', 'carta', 'debajo', 'de', 'estos', 'papeles.']),
#  ('__label__spa',
#   ['Tom', 'fue', 'a', 'París', 'para', 'estudiar', 'francés.']),
#  ('__label__por', ['Nós', 'perdemos', 'a', 'fé', 'na', 'humanidade.']),
#  ('__label__por',
#   ['Essas',
#    'são',
#    'todas',
#    'as',
#    'perguntas',
#    'que',
#    'eu',
#    'irei',
#    'responder',
#    'agora.']),
#  ('__label__por',
#   ['Layla', 'tornou-se', 'amante', 'de', 'seu', 'inquilino,', 'Fadil.']),
#  ('__label__ita',
#   ['Quando',
#    "s'è",
#    'fatto',
#    'più',
#    'freddo',
#    'durante',
#    'il',
#    'giorno,',
#    'ho',
#    'dovuto',
#    'indossare',
#    'un',
#    'maglione.']),
#  ('__label__por', ['Faz', 'um', 'calor', 'insuportável', 'neste', 'verão.']),
#  ('__label__rus',
#   ['Его', 'друзья', 'были', 'рады', 'снова', 'его', 'видеть.']),
#  ('__label__tur', ['Tom', 'doktorunun', 'emirlerine', 'uymadı.']),
#  ('__label__hun', ['Tettél', 'már', 'lépéseket', 'ebben', 'az', 'ügyben?']),
#  ('__label__spa',
#   ['El', 'corredor', 'apretó', 'en', 'la', 'última', 'vuelta.']),
#  ('__label__epo', ['Ĉu', 'ne', 'odoras', 'iel', 'bizare?']),
#  ('__label__tur',
#   ['Paraya',
#    'ihtiyacım',
#    'var',
#    've',
#    'senin',
#    'bana',
#    'yardım',
#    'etmene',
#    'ihtiyacım',
#    'var.']),
#  ('__label__eng', ['Where', 'did', 'she', 'go', 'fishing?']),
#  ('__label__por',
#   ['Eu',
#    'mesmo',
#    'já',
#    'paguei',
#    'multas',
#    'por',
#    'estacionamento',
#    'proibido',
#    'algumas',
#    'vezes.']),
#  ('__label__ita',
#   ['Tom', 'è', 'stato', 'un', 'insegnante', 'per', 'quasi', "trent'anni."]),
#  ('__label__por',
#   ['Eu', 'nasci', 'no', 'norte,', 'mas', 'agora', 'moro', 'na', 'Flórida.']),
#  ('__label__eng',
#   ['Sami',
#    'failed',
#    'to',
#    'mention',
#    'he',
#    'was',
#    'a',
#    'convicted',
#    'felon.']),
#  ('__label__rus', ['Лучше', 'нам', 'немного', 'подождать.']),
#  ('__label__rus',
#   ['С',
#    'увеличением',
#    'научных',
#    'знаний,',
#    'склонность',
#    'человека',
#    'ко',
#    'злу',
#    'увеличивается',
#    'в',
#    'той',
#    'же',
#    'пропорции,',
#    'как',
#    'склонность',
#    'к',
#    'добру.']),
#  ('__label__eng', ['The', 'wheat', 'will', 'be', 'ripe.']),
#  ('__label__hun', ['Tom', 'hallotta', 'Maryt', 'köhögni.']),
#  ('__label__rus', ['Вам', 'надо', 'начать.']),
#  ('__label__ita', ['Nessun', 'TG', 'ne', 'ha', 'ancora', 'parlato.']),
#  ('__label__eng', ['Sami', 'was', 'a', 'vicious', 'malicious', 'salesman.']),
#  ('__label__deu', ['Artemis', 'ist', 'Apollos', 'Schwester.']),
#  ('__label__eng', ['Mary', 'lost', 'her', 'car', 'key.']),
#  ('__label__rus',
#   ['Неизвестно,',
#    'когда',
#    'это',
#    'произошло,',
#    'но,',
#    'очевидно,',
#    'это',
#    'было',
#    'давно.']),
#  ('__label__tur', ['Tom', 'daha', 'fazla', 'soru', 'sormadı.']),
#  ('__label__eng', ['It', "isn't", 'easy.']),
#  ('__label__ita', ['Tom', 'ha', 'avuto', "un'infanzia", 'difficile.']),
#  ('__label__hun', ['Tom', 'nagyon', 'ijedt', 'volt.']),
#  ('__label__hun',
#   ['A',
#    'skót',
#    'Nemzeti',
#    'párt',
#    'elveszítette',
#    'az',
#    'abszolút',
#    'többségét',
#    'a',
#    'skót',
#    'parlamentben.']),
#  ('__label__deu', ['Er', 'hat', 'das', 'sehr', 'krumm', 'genommen.']),
#  ('__label__rus', ['Том', 'вас', 'защитит.']),
#  ('__label__epo', ['Li', 'devis', 'resti', 'enlite.']),
#  ('__label__tur',
#   ['Mary', "Tom'un", 'sorumluluktan', 'korktuğunu', 'düşünüyor.']),
#  ('__label__rus',
#   ['Каков',
#    'уровень',
#    'образования',
#    'вашего',
#    'родителя',
#    'или',
#    'опекуна?']),
#  ('__label__epo', ['Tomo', 'havas', 'kelkajn', 'tatuojn,', 'ĉu', 'ne?']),
#  ('__label__rus', ['Приблизься.']),
#  ('__label__rus', ['Засыпай,', 'братец!']),
#  ('__label__eng',
#   ['We',
#    'should',
#    'tell',
#    'Tom',
#    'that',
#    'Mary',
#    "doesn't",
#    'want',
#    'him',
#    'to',
#    'come.']),
#  ('__label__eng', ['I', 'love', 'this', 'song.']),
#  ('__label__por',
#   ['Eu', 'preciso', 'de', 'um', 'copo', 'de', 'vinho', 'agora.']),
#  ('__label__ita',
#   ['Sembra', 'che', 'abbiate', 'cambiato', 'completamente', 'camera.']),
#  ('__label__ita',
#   ['Le', 'frasi', 'di', 'Dan', 'sono', 'facili', 'da', 'tradurre.']),
#  ('__label__deu',
#   ['Weil',
#    'das',
#    'Wetter',
#    'schlecht',
#    'ist,',
#    'kann',
#    'man',
#    'nicht',
#    'Golf',
#    'spielen;',
#    'deswegen',
#    'ist',
#    'Mutters',
#    'Stimmung',
#    'sehr',
#    'schlecht.']),
#  ('__label__deu', ['Sie', 'hat', 'ihm', 'den', 'Kopf', 'verdreht.']),
#  ('__label__ita', ['Le', 'piacerà', 'questo', 'gioco.']),
#  ('__label__deu', ['Ihre', 'Schönheit', 'lässt', 'mich', 'erblassen.']),
#  ('__label__rus',
#   ['«Слушай,',
#    'хватит',
#    'перебивать!»',
#    '—',
#    '«Хорошо,',
#    'хорошо!',
#    'Молчу.',
#    'Рассказывай',
#    'дальше...',
#    'Пожалуйста!»',
#    '—',
#    'определённо,',
#    'Мэри',
#    'была',
#    'сама',
#    'невинность.']),
#  ('__label__ita', ['Andiamo', 'in', 'Uruguay.']),
#  ('__label__tur', ['Kaybetmek', 'hiç', 'eğlenceli', 'değil.']),
#  ('__label__hun', ['Ki', 'vigyáz', 'rád?']),
#  ('__label__spa', ['Madre,', 'algo', 'huele', 'a', 'quemado.']),
#  ('__label__fra', ['Elle', 'est', 'de', 'très', 'bonne', 'humeur.']),
#  ('__label__ita', ['Vanno', 'a', 'costruire', 'mattatoi', 'in', 'Russia?']),
#  ('__label__eng', ['Tom', 'is', 'still', 'just', 'a', 'kid.']),
#  ('__label__fra', ['Elle', 'lui', 'a', 'foutu', 'sur', 'la', 'gueule.']),
#  ('__label__tur',
#   ['Jane', 'biraz', 'para', 'çekmek', 'için', 'bankaya', 'gitti.']),
#  ('__label__ita', ['Telefonami', 'se', 'piove.']),
#  ('__label__rus', ['Как', 'соотносятся', 'права', 'и', 'обязанности?']),
#  ('__label__epo', ['Manjo', 'faris', 'multajn', 'erarojn.']),
#  ('__label__fra',
#   ['Je',
#    "n'ai",
#    'jamais',
#    'frappé',
#    'qui',
#    'que',
#    'ce',
#    'soit',
#    'de',
#    'ma',
#    'vie.']),
#  ('__label__deu',
#   ['Tom', 'und', 'Peter', 'kommen,', 'sie', 'sind', 'pünktlich.']),
#  ('__label__rus',
#   ['"Привет,',
#    'могу',
#    'я',
#    'поговорить',
#    'с',
#    'Мауро?"',
#    '-',
#    '"Да,',
#    'кто',
#    'звонит?"']),
#  ('__label__eng', ['Tom', 'seldom', 'goes', 'jogging', 'anymore.']),
#  ('__label__epo', ['Kion', 'vi', 'volas', 'plu', 'ŝanĝi?']),
#  ('__label__rus', ['Иногда', 'я', 'его', 'не', 'понимаю.']),
#  ('__label__eng',
#   ['I', 'know', 'Tom', 'and', 'Mary', 'are', 'waiting', 'for', 'us.']),
#  ('__label__rus',
#   ['Мальчик', 'был', 'на', 'грани', 'того,', 'чтобы', 'утонуть.']),
#  ('__label__tur',
#   ['Yılan',
#    'daha',
#    'büyük',
#    'bir',
#    'yılan',
#    'tarafından',
#    'mideye',
#    'indirildi.']),
#  ('__label__rus', ['Я', 'принёс', 'вино.']),
#  ('__label__epo', ['Lasu', 'nin', 'ludi,', 'frateto!']),
#  ('__label__tur',
#   ['Sadece',
#    'yaşadığım',
#    'yerden',
#    'bir',
#    'blok',
#    'ötede',
#    "Boston'da",
#    'tam',
#    'burada',
#    'yaşadığına',
#    'inanamıyorum.']),
#  ('__label__epo', ['Tiu', 'ĉi', 'frazo', 'ne', 'estas', 'en', 'la', 'itala.']),
#  ('__label__tur', ['Bunu', 'kimin', 'yapacağını', 'merak', 'ediyorum.']),
#  ('__label__tur', ['O', 'benim', 'kaybolacağımdan', 'korkuyor.']),
#  ('__label__tur', ['Şükründen', 'acizim.']),
#  ('__label__eng', ['Give', 'him', 'a', 'day', 'or', 'two.']),
#  ('__label__eng',
#   ['What',
#    'on',
#    'earth',
#    'were',
#    'you',
#    'thinking,',
#    'bringing',
#    'him',
#    'here?']),
#  ('__label__por', ['Lê', 'a', 'tabuleta.']),
#  ('__label__eng',
#   ['Tom',
#    'is',
#    'going',
#    'to',
#    'stay',
#    'in',
#    'Australia',
#    'until',
#    'the',
#    'end',
#    'of',
#    'October.']),
#  ('__label__por',
#   ['Ele', 'pegou', 'o', 'ônibus', 'errado', 'de', 'novo,', 'não', 'é?']),
#  ('__label__ita',
#   ['I',
#    'giapponesi',
#    'si',
#    'tolgono',
#    'le',
#    'scarpe',
#    'quando',
#    'entrano',
#    'in',
#    'una',
#    'casa.']),
#  ('__label__tur', ['Polisler', 'beni', 'tutukladı.']),
#  ('__label__eng',
#   ['John',
#    'took',
#    'the',
#    "lion's",
#    'share',
#    'of',
#    'the',
#    'lottery',
#    'winnings;',
#    'he',
#    'claimed',
#    'it',
#    'was',
#    'his',
#    'idea',
#    'to',
#    'buy',
#    'the',
#    'ticket',
#    'in',
#    'the',
#    'first',
#    'place.']),
#  ('__label__tur', ['Sahip', 'olduğu', 'her', 'fırsattan', 'yararlandı.']),
#  ('__label__ita', ['Andiamo', 'a', 'fare', 'carriera', 'in', 'Brasile?']),
#  ('__label__tur',
#   ['Ben', "Tom'un", 'ayakkabılarını', 'onun', 'için', 'cilaladım.']),
#  ('__label__tur',
#   ['Onların', 'hazır', 'olduğundan', 'emin', 'olmak', 'zorundayız.']),
#  ('__label__tur', ['Onun', 'sırrını', 'öğrenmeye', 'meraklıydı.']),
#  ('__label__deu',
#   ['Du',
#    'solltest',
#    'Tom',
#    'sagen,',
#    'dass',
#    'du',
#    'das',
#    'nicht',
#    'tun',
#    'möchtest.']),
#  ('__label__fra', ['Huit', 'moins', 'quatre', 'font', 'quatre.']),
#  ('__label__ita', ['Non', 'ho', 'paura', 'delle', 'donne.']),
#  ('__label__eng', ['Some', 'books', 'are', 'on', 'the', 'table.']),
#  ('__label__spa',
#   ['Siento',
#    'que',
#    'es',
#    'muy',
#    'difícil',
#    'que',
#    'me',
#    'ponga',
#    'a',
#    'la',
#    'par',
#    'con',
#    'él',
#    'en',
#    'matemáticas.']),
#  ('__label__rus', ['Я', 'рад', 'вас', 'видеть,', 'мистер', 'Ито.']),
#  ('__label__ita', ['Il', 'mio', 'migliore', 'amico', 'era', 'cinese.']),
#  ('__label__eng',
#   ['Tom', 'and', 'Mary', 'said', 'they', 'were', 'getting', 'hungry.']),
#  ('__label__tur',
#   ['Asistanım', 'otuz', 'yaşındaki', 'Kanadalı', 'bir', 'adam.']),
#  ('__label__hun', ['Tom', 'súlya', 'kb.', '136', 'kiló.']),
#  ('__label__hun',
#   ['Jelölje', 'meg', 'azon', 'szavakat,', 'melyeket', 'nem', 'ért.']),
#  ('__label__ita', ['Andate', 'con', 'Tom.']),
#  ('__label__eng',
#   ['Mary', 'told', 'me', 'she', "hasn't", 'done', 'that', 'yet.']),
#  ('__label__eng',
#   ['Tom', 'should', 'probably', 'tell', 'Mary', 'not', 'to', 'be', 'afraid.']),
#  ('__label__por', ['Vês', 'a', 'rosa?']),
#  ('__label__fra', ['Je', 'ne', 'sais', 'que', 'faire', '!']),
#  ('__label__tur',
#   ['Tom', 'bana', 'kurabiye', 'teklif', 'etti', 'ama', 'ben', 'reddettim.']),
#  ('__label__epo', ['Oni', 'parolas', 'la', 'anglan', 'en', 'Singapuro.']),
#  ('__label__rus', ['Вам', 'хотелось', 'спать.']),
#  ('__label__por', ['Mary', 'parecia', 'estar', 'nervosa.']),
#  ('__label__rus', ['Он', 'не', 'очень-то', 'любит', 'работать.']),
#  ('__label__fra', ['Mon', 'oncle', 'est', 'venu', 'me', 'voir.']),
#  ('__label__ita',
#   ['Che',
#    'tipo',
#    'di',
#    'comportamento',
#    'considera',
#    'in',
#    'generale',
#    'come',
#    'tipicamente',
#    'maschile?']),
#  ('__label__deu',
#   ['Bei',
#    'dem',
#    'Angriff',
#    'sollen',
#    'Panzer',
#    'und',
#    'Scharfschützen',
#    'eingesetzt',
#    'worden',
#    'sein.']),
#  ('__label__ita', ['Ho', 'un', 'fratello.']),
#  ('__label__eng',
#   ["I'm", 'a', 'poor', 'student', 'and', 'I', "can't", 'pay', 'you.']),
#  ('__label__epo', ['Tomo', 'estas', 'ĉi', 'tie', 'por', 'helpi', 'nin.']),
#  ('__label__rus',
#   ['Сегодня',
#    'тепло,',
#    'светит',
#    'солнышко,',
#    'и',
#    'я',
#    'очень',
#    'счастливый.']),
#  ('__label__eng', ['I', "wasn't", 'tired.']),
#  ('__label__deu',
#   ['Der', 'Schaden', 'war', 'durch', 'die', 'Versicherung', 'abgedeckt.']),
#  ('__label__fra', ['Pourquoi', "t'opposes-tu", 'aux', 'gens', '?']),
#  ('__label__eng', ['He', 'said', 'that', 'he', 'was', 'amused.']),
#  ('__label__hun', ['Őszintén', 'szólva', 'én', 'is', 'szeretnék', 'menni.']),
#  ('__label__eng', ['I', 'went', 'to', 'Boston', 'for', 'a', 'job.']),
#  ('__label__eng',
#   ['Salt',
#    'and',
#    'pepper',
#    'completely',
#    'and',
#    'add',
#    'a',
#    'dash',
#    'of',
#    'nutmeg.']),
#  ('__label__deu',
#   ['Sie',
#    'ist',
#    'sich',
#    'im',
#    'Unklaren,',
#    'was',
#    'sie',
#    'wirklich',
#    'will.']),
#  ('__label__ita',
#   ['Io',
#    'ho',
#    'pensato',
#    'per',
#    'un',
#    'attimo',
#    'che',
#    'noi',
#    'avessimo',
#    'un',
#    'problema.']),
#  ('__label__ita',
#   ['Non',
#    'importa',
#    'quanto',
#    'voi',
#    'possiate',
#    'essere',
#    'stanche,',
#    'dovete',
#    'farlo.']),
#  ('__label__ita', ['Voi', 'potete', 'venire', 'domani?']),
#  ('__label__por', ['Nós', 'a', 'encontramos', 'com', 'vida.']),
#  ('__label__eng', ['Stop', 'treating', 'me', 'like', 'a', 'kid.']),
#  ('__label__eng',
#   ['If',
#    'Tom',
#    'had',
#    'been',
#    'a',
#    'little',
#    'more',
#    'patient,',
#    'he',
#    'would',
#    'have',
#    'been',
#    'able',
#    'to',
#    'do',
#    'that.']),
#  ('__label__spa', ['Mi', 'caballo', 'es', 'blanco.']),
#  ('__label__fra', ["J'ai", 'beaucoup', "d'amis", 'francophones.']),
#  ('__label__hun', ['Jó', 'lenne,', 'ha', 'nem', 'pereskednénk.']),
#  ('__label__ita', ['Credevi', 'a', 'Tom?']),
#  ('__label__eng', ['He', 'is', 'afraid', 'of', 'getting', 'lung', 'cancer.']),
#  ('__label__rus',
#   ['Ни',
#    'разу',
#    'не',
#    'было,',
#    'чтобы',
#    'Том',
#    'пришёл',
#    'вовремя.',
#    'Он',
#    'всегда',
#    'опаздывает.']),
#  ('__label__epo', ['Hodiaŭ', 'mi', 'sentas', 'min', 'iomete', 'malĝoja.']),
#  ('__label__ita', ['Li', 'consultammo', 'sulla', 'questione.']),
#  ('__label__eng',
#   ['Tom', 'wants', 'you', 'to', 'be', 'his', 'date', 'for', 'the', 'prom.']),
#  ('__label__rus', ['Том', 'снял', 'свитер.']),
#  ('__label__rus', ['Дети,', 'вы', 'знаете', 'эту', 'игру?']),
#  ('__label__epo', ['Ni', 'estis', 'devigataj', 'diligente', 'labori.']),
#  ('__label__eng', ['I', 'thought', 'Tom', 'and', 'Mary', 'were', 'tired.']),
#  ('__label__fra', ['Je', "n'ai", 'pas', 'compris', "l'erreur."]),
#  ('__label__epo',
#   ['La', 'sola', 'bona,', 'trafa', 'propagando', 'estas', 'la', 'ekzemplo.']),
#  ('__label__eng',
#   ['Markku',
#    '–',
#    'who',
#    'likes',
#    'to',
#    'fish',
#    '–',
#    'caught',
#    'a',
#    'large',
#    'fish',
#    'today.']),
#  ('__label__tur',
#   ["Tom'un", 'onu', 'yapmayı', 'neden', 'sevdiğini', 'merak', 'ediyorum.']),
#  ('__label__deu',
#   ['Mein',
#    'Vater',
#    'hat',
#    'schon',
#    'aufgehört',
#    'zu',
#    'trinken',
#    'und',
#    'zu',
#    'rauchen.']),
#  ('__label__epo', ['Tomo', 'estis', 'varme', 'akceptita.']),
#  ('__label__spa', ['Tenemos', 'cinco', 'tipos', 'de', 'kebab.']),
#  ('__label__rus', ['Том', 'завтра', 'выиграет.']),
#  ('__label__tur',
#   ['Tom', 'yardım', 'etmek', 'için', 'bir', 'şey', 'yapmak', 'istedi.']),
#  ('__label__spa',
#   ['Estaban',
#    'haciendo',
#    'un',
#    'puente',
#    'a',
#    'mi',
#    'coche',
#    'cuando',
#    'los',
#    'sorprendí.']),
#  ('__label__eng',
#   ['Tom',
#    "must've",
#    'thought',
#    'Mary',
#    "didn't",
#    'want',
#    'to',
#    'do',
#    'that.']),
#  ('__label__eng',
#   ['There', 'were', 'at', 'least', '100', 'people', 'present.']),
#  ('__label__tur', ['Neredeyse', 'hiç', 'Fransızca', 'konuşamam.']),
#  ('__label__rus', ['Она', 'ждала,', 'пока', 'я', 'не', 'приду.']),
#  ('__label__tur',
#   ["Tom'a",
#    "Mary'nin",
#    'söylediğine',
#    'inanmamasını',
#    'tavsiye',
#    'etmeliydim.']),
#  ('__label__eng',
#   ['When',
#    'I',
#    'came',
#    'home,',
#    'my',
#    'sister',
#    'was',
#    'playing',
#    'the',
#    'guitar.']),
#  ('__label__deu', ['Ich', 'habe', 'immer', 'noch', 'Hunger.']),
#  ('__label__deu',
#   ['Ich',
#    'gebe',
#    'gerne',
#    'jedes',
#    'Jahr',
#    'etwas',
#    'Geld',
#    'für',
#    'wohltätige',
#    'Zwecke.']),
#  ('__label__eng', ['She', 'always', 'wears', 'her', 'seatbelt.']),
#  ('__label__hun',
#   ['Tom',
#    'több',
#    'bizalmat',
#    'adott',
#    'Marinak,',
#    'mint',
#    'amennyit',
#    'megérdemelt.']),
#  ('__label__epo',
#   ['Ŝi', 'volas', 'ion', 'tre', 'specialan', 'por', 'sia', 'naskiĝtago.']),
#  ('__label__por', ['Pelo', 'menos', 'eu', 'tenho', 'onde', 'dormir.']),
#  ('__label__tur', ['Ondan', 'bir', 'iyilik', 'istedim.']),
#  ('__label__eng', ['Sami', 'raised', 'some', 'suspicion.']),
#  ('__label__eng', ['Layla', 'will', 'make', 'you', 'lose', 'your', 'mind.']),
#  ('__label__fra', ['Le', 'tien', 'était', 'meilleur.']),
#  ('__label__eng', ["We've", 'all', 'seen', 'it', 'before.']),
#  ('__label__ita', ['Pagherai', 'per', 'quello', 'che', 'hai', 'fatto!']),
#  ('__label__ita', ['Non', 'sapete', 'ancora', 'il', 'mio', 'nome,', 'vero?']),
#  ('__label__tur', ['Ben', 'ailenin', 'yüz', 'karasıyım.']),
#  ('__label__spa',
#   ['Si',
#    'hay',
#    'muchas',
#    'señales',
#    'juntas,',
#    'los',
#    'conductores',
#    'se',
#    'despistan.']),
#  ('__label__spa', ['¿Pero', 'no', 'debías', 'salir?']),
#  ('__label__rus', ['Том', 'говорил', 'сердитым', 'тоном.']),
#  ('__label__deu',
#   ['Ein',
#    'Leuchten',
#    'ging',
#    'über',
#    'das',
#    'Gesicht',
#    'der',
#    'beiden',
#    'Kinder.']),
#  ('__label__epo',
#   ['Kiam', 'li', 'estas', 'kolera,', 'li', 'ĉiam', 'krias', 'al', 'mi.']),
#  ('__label__eng',
#   ['You', 'can', 'get', 'a', 'better', 'look', 'over', 'here.']),
#  ('__label__epo', ['Mia', 'nomo', 'estas', 'Sascha.']),
#  ('__label__rus', ['Том', 'был', 'разведён.']),
#  ('__label__hun',
#   ['Az', 'apa', 'mérges', 'volt', 'a', 'kései', 'hazatérés', 'miatt.']),
#  ('__label__epo',
#   ['Tomo',
#    'opiniis',
#    'la',
#    'veston',
#    'de',
#    'Manjo',
#    'maltaŭga',
#    'por',
#    'la',
#    'okazo.']),
#  ('__label__eng',
#   ['This', 'is', 'taking', 'longer', 'than', 'I', 'thought', 'it', 'would.']),
#  ('__label__epo',
#   ['Ĉu', 'okazos', 'interproksimiĝo', 'de', 'ambaŭ', 'konfliktantoj?']),
#  ('__label__eng',
#   ['Even',
#    'though',
#    'Tom',
#    'has',
#    'never',
#    'even',
#    'tried',
#    'eating',
#    'one,',
#    'he',
#    'says',
#    'he',
#    "doesn't",
#    'like',
#    'kiwifruit.']),
#  ('__label__spa', ['Tom', 'aún', 'no', 'ha', 'abierto', 'su', 'tienda.']),
#  ('__label__spa',
#   ['¿Debería',
#    'comprar',
#    'este',
#    'diccionario',
#    'solo',
#    'porque',
#    'es',
#    'barato?']),
#  ('__label__eng', ['She', 'says', 'she', 'wants', 'to', 'meet', 'you.']),
#  ('__label__tur',
#   ['Eğer',
#    'bunu',
#    'benim',
#    'için',
#    'yapsaydınız',
#    'çok',
#    'memnun',
#    'olurdum.']),
#  ('__label__eng', ['Tom', 'told', 'Mary', 'you', 'went', 'to', 'Boston.']),
#  ('__label__ita', ['Io', 'sto', 'parlando', 'con', 'loro.']),
#  ('__label__eng',
#   ['I', 'was', 'hoping', 'Tom', 'would', 'ask', 'me', 'to', 'sing.']),
#  ('__label__por', ['Tom', 'se', 'esqueceu', 'de', 'apagar', 'a', 'luz.']),
#  ('__label__eng', ['Thank', 'you', 'very', 'much', 'for', 'your', 'gift.']),
#  ('__label__ita',
#   ['Penso', 'che', 'andrai', 'per', 'soldi', 'in', 'Sudafrica.']),
#  ('__label__rus', ['Пей', 'до', 'дна!']),
#  ('__label__eng',
#   ['I',
#    "didn't",
#    'know',
#    'that',
#    'Tom',
#    'knew',
#    'anyone',
#    'who',
#    'did',
#    'that.']),
#  ('__label__eng', ['Tom', 'put', 'his', 'camera', 'into', 'his', 'pocket.']),
#  ('__label__ita', ['Non', 'sarà', 'mai', 'felice.']),
#  ('__label__ita', ['Io', 'non', 'sono', 'fiera', 'di', 'mio', 'figlio.']),
#  ('__label__ita',
#   ['Ha',
#    'perso',
#    'molto',
#    'peso',
#    'da',
#    'quando',
#    'si',
#    'è',
#    'messa',
#    'a',
#    'dieta.']),
#  ('__label__ita',
#   ['Il', 'Giappone', 'esporta', 'molte', 'automobili', "all'estero."]),
#  ('__label__rus', ['Охранники', 'не', 'видели', 'Тома.']),
#  ('__label__eng', ['Tom', 'said', 'that', 'he', 'wanted', 'a', 'lawyer.']),
#  ('__label__rus', ['Он', 'уже', 'пять', 'лет', 'как', 'умер.']),
#  ('__label__por',
#   ['O', 'Tom', 'estava', 'irritado,', 'mas', 'a', 'Mary', 'não', 'estava.']),
#  ('__label__eng',
#   ['I',
#    'have',
#    'looked',
#    'everywhere,',
#    'but',
#    'I',
#    'can',
#    'not',
#    'find',
#    'my',
#    'wallet.']),
#  ('__label__rus', ['Вот', 'ваша', 'плата', 'за', 'беспокойство.']),
#  ('__label__epo', ['Tiu', 'diskuto', 'ne', 'novas.']),
#  ('__label__deu',
#   ['Er', 'verspätete', 'sich', 'zu', 'seiner', 'eigenen', 'Hochzeit.']),
#  ('__label__eng',
#   ['Tom',
#    'wants',
#    'to',
#    'finish',
#    'eating',
#    'before',
#    'he',
#    'talks',
#    'to',
#    'anyone.']),
#  ('__label__deu', ['Es', 'war', 'kein', 'Unfall.']),
#  ('__label__ita', ['Suonerete', 'con', 'Naoko', 'questo', 'pomeriggio.']),
#  ('__label__rus', ['Мы', 'этого', 'не', 'забыли.']),
#  ('__label__fra',
#   ['Vous',
#    'pouvez',
#    'mettre',
#    'vos',
#    'affaires',
#    'dans',
#    'le',
#    'casier',
#    'puis',
#    'choisir',
#    'un',
#    'code',
#    'pour',
#    'le',
#    'fermer.']),
#  ('__label__epo', ['Mi', 'povas', 'kredi', 'tion.']),
#  ('__label__epo', ['Li', 'tuŝis', 'mian', 'ŝultron.']),
#  ('__label__eng',
#   ['This', 'department', 'store', 'is', 'closed', 'at', 'seven.']),
#  ('__label__eng',
#   ['How', 'long', 'do', 'you', 'expect', 'Tom', 'to', 'stay', 'here?']),
#  ('__label__rus', ['Все', 'перестали', 'работать.']),
#  ('__label__hun', ['Stewardesst', 'vett', 'feleségül.']),
#  ('__label__tur',
#   ['Bu', 'köprü', 'aslında', 'geçiş', 'ücreti', 'alınan', 'bir', 'köprüydü.']),
#  ('__label__ita', ["Quest'uomo", 'è', 'molto', 'generoso.']),
#  ('__label__hun', ['Jókedve', 'volt.']),
#  ('__label__eng', ['Is', 'fast', 'food', 'really', 'healthy?']),
#  ('__label__fra', ['Il', 'acceptait', 'les', 'cadeaux.']),
#  ('__label__fra',
#   ['Seuls',
#    'ceux',
#    'avec',
#    'une',
#    'autorisation',
#    'de',
#    'sécurité',
#    'sont',
#    'acceptés',
#    'après',
#    'ce',
#    'point.']),
#  ('__label__eng',
#   ["Don't", 'let', 'them', 'know', "they're", 'being', 'watched.']),
#  ('__label__rus', ['Я', 'пошёл', 'в', 'магазин.']),
#  ('__label__eng', ['This', 'is', 'just', 'a', 'temporary', 'break', 'up.']),
#  ('__label__epo',
#   ['Kion',
#    'faros',
#    'Trump',
#    'nun?',
#    'Ĉu',
#    'ataki',
#    'Ĉinion?',
#    'Ĉu',
#    'detrui',
#    'Rusion?',
#    'Ĉu',
#    'neniigi',
#    'Iranon?',
#    'Li',
#    'faros',
#    'nenion,',
#    'ĉar',
#    'Usono',
#    'jam',
#    'provis',
#    'fari',
#    'ĉion',
#    'ĉi',
#    'jam',
#    'delonge,',
#    'sed',
#    'ĝi',
#    'kompatindege',
#    'malsukcesis',
#    'en',
#    'tio.']),
#  ('__label__spa', ['Tenía', 'otra', 'cosa', 'en', 'la', 'cabeza.']),
#  ('__label__ita', ['Ma', 'le', 'favole', 'finiscono', 'male?']),
#  ('__label__epo', ['Li', 'nepre', 'notos', 'vian', 'eraron.']),
#  ('__label__epo',
#   ['Mi',
#    'ne',
#    'scias,',
#    'ĉu',
#    'vi',
#    'jam',
#    'iam',
#    'spertis',
#    'tiun',
#    'senton.']),
#  ('__label__rus', ['Какую', 'религию', 'вы', 'исповедуете?']),
#  ('__label__por', ['Estou', 'atualizando', 'meus', 'conhecimentos.']),
#  ('__label__hun',
#   ['Köszönöm,', 'hogy', 'szóltál', 'az', 'elgépelés', 'miatt.']),
#  ('__label__deu', ['Ich', 'halte', 'es', 'nicht', 'mehr', 'länger', 'aus.']),
#  ('__label__ita',
#   ['La',
#    'notizia',
#    'della',
#    'morte',
#    'di',
#    'suo',
#    'figlio',
#    'fu',
#    'per',
#    'lui',
#    'un',
#    'bruttissimo',
#    'colpo.']),
#  ('__label__rus', ['Я', 'высоко', 'мечу.']),
#  ('__label__epo',
#   ['Ĝi',
#    'estas',
#    'ekzakte',
#    'la',
#    'loko,',
#    'kiun',
#    'mi',
#    'deziris',
#    'viziti',
#    'jam',
#    'de',
#    'longe.']),
#  ('__label__rus',
#   ['Я',
#    'не',
#    'представляю,',
#    'как',
#    'Том',
#    'выдержал',
#    'все',
#    'эти',
#    'годы',
#    'с',
#    'Мэри.']),
#  ('__label__rus', ['Всё', 'так', 'вкусно', 'пахнет.']),
#  ('__label__rus', ['Мы', 'не', 'дадим', 'вам', 'умереть.']),
#  ('__label__eng', ['How', 'interesting', 'is', 'that!']),
#  ('__label__rus', ['Я', 'думаю,', 'что', 'Том', 'остроумен.']),
#  ('__label__spa',
#   ['¡No',
#    'me',
#    'digas',
#    'que',
#    'ya',
#    'es',
#    'hora',
#    'de',
#    'irnos!',
#    '¡Se',
#    'me',
#    'había',
#    'ido',
#    'el',
#    'santo',
#    'al',
#    'cielo!']),
#  ('__label__tur', ['O', 'çok', 'uygunsuz', 'olurdu.']),
#  ('__label__eng',
#   ['According',
#    'to',
#    "Newton's",
#    'second',
#    'law',
#    'of',
#    'motion,',
#    'a',
#    'force',
#    'is',
#    'produced',
#    'when',
#    'a',
#    'mass',
#    'is',
#    'accelerated.']),
#  ('__label__deu', ['Rauch', 'nicht', 'zu', 'viel.']),
#  ('__label__eng',
#   ['Tom',
#    'and',
#    'Mary',
#    "can't",
#    'have',
#    'done',
#    'that',
#    'by',
#    'themselves.']),
#  ('__label__rus', ['Почему', 'он', 'всем', 'так', 'нравится?']),
#  ('__label__fra', ["C'est", 'un', 'tireur', "d'élite."]),
#  ('__label__ita', ['Penso', 'che', 'fosse', 'terrificante.']),
#  ('__label__tur', ['Bu', 'adam', 'mutlak', 'bir', 'dahi.']),
#  ('__label__hun', ['Ijesztő', 'idelent.']),
#  ('__label__ita', ['Noi', 'sappiamo', 'nuotare.']),
#  ('__label__por',
#   ['Tom',
#    'não',
#    'pôde',
#    'descobrir',
#    'como',
#    'Maria',
#    'conseguiu',
#    'permanecer',
#    'viva.']),
#  ('__label__eng', ['That', 'seems', 'to', 'be', 'the', 'problem.']),
#  ('__label__spa',
#   ['La',
#    'carta',
#    'está',
#    'fechada',
#    'el',
#    '1º',
#    'de',
#    'abril',
#    'de',
#    '1987.']),
#  ('__label__ita', ['Noi', 'urleremo.']),
#  ('__label__eng', ['Layla', 'was', 'taking', 'a', 'bath.']),
#  ('__label__ita', ['Tu', 'hai', 'aspettato', 'dieci', 'minuti.']),
#  ('__label__por', ['É', 'a', 'dura', 'realidade!']),
#  ('__label__eng',
#   ['Tom',
#    'rubbed',
#    'the',
#    'stone',
#    'that',
#    'the',
#    'good',
#    'fairy',
#    'had',
#    'given',
#    'him,',
#    'whereupon',
#    'he',
#    'turned',
#    'into',
#    'a',
#    'squirrel',
#    'and',
#    'could',
#    'escape',
#    'to',
#    'freedom',
#    'through',
#    'the',
#    'bars',
#    'of',
#    'the',
#    'prison',
#    'window',
#    'with',
#    'ease.']),
#  ('__label__tur', ['Bugün', 'hava', 'bulutlu', 'mu?']),
#  ('__label__eng', ['You', 'are', 'my', 'leader.']),
#  ('__label__spa',
#   ['Tom',
#    'alimentó',
#    'al',
#    'gato',
#    'de',
#    'los',
#    'vecinos',
#    'mientras',
#    'ellos',
#    'estaban',
#    'fuera.']),
#  ('__label__ita', ['Il', 'mio', 'migliore', 'amico', 'non', 'era', 'rumeno?']),
#  ('__label__eng', ['Sami', 'drowned', 'in', 'his', 'pool.']),
#  ('__label__tur', ['Sen', 'onu', 'geri', 'alamazsın.']),
#  ('__label__eng',
#   ["Don't", 'forget', 'Tom', 'has', 'no', 'sense', 'of', 'humor.']),
#  ('__label__eng', ['Tom', 'asked', 'Mary', 'for', 'her', 'phone', 'number.']),
#  ('__label__ita', ["L'ho", 'vista', 'questa', 'sera.']),
#  ('__label__eng', ["It's", 'nice', 'you', 'found', 'a', 'girlfriend.']),
#  ('__label__por',
#   ['Gosto', 'muito', 'da', 'segunda', 'parte', 'do', 'vídeo.']),
#  ('__label__eng',
#   ['I', 'cannot', 'lick', 'my', 'fingers.', "I'm", 'not', 'a', 'cat.']),
#  ('__label__eng',
#   ['Mary', 'will', 'be', 'fired', 'if', 'she', 'does', 'that', 'again.']),
#  ('__label__rus',
#   ['«Я',
#    'сегодня',
#    'первый',
#    'раз',
#    'со',
#    'своим',
#    'интернет-другом',
#    'встречалась».',
#    '—',
#    '«А,',
#    'это',
#    'с',
#    'тем',
#    'Томом,',
#    'про',
#    'которого',
#    'ты',
#    'всё',
#    'время',
#    'рассказываешь?»',
#    '—',
#    '«Ага,',
#    'с',
#    'ним».',
#    '—',
#    '«Ну',
#    'и',
#    'как',
#    'всё',
#    'прошло?»',
#    '—',
#    '«Оказался',
#    'не',
#    'таким',
#    'клёвым,',
#    'как',
#    'я',
#    'надеялась».']),
#  ('__label__fra', ['Elle', 'obéit', 'aveuglement', 'à', 'sa', 'directrice.']),
#  ('__label__por',
#   ['Fadil', 'não', 'está', 'aqui.', 'Sabe', 'onde', 'ele', 'está?']),
#  ('__label__deu', ['Tom', 'fragt', 'so', 'gut', 'wie', 'nie', 'etwas.']),
#  ('__label__por',
#   ['Jornais',
#    'e',
#    'redes',
#    'de',
#    'televisão',
#    'no',
#    'mundo',
#    'todo',
#    'contaram',
#    'a',
#    'história',
#    'de',
#    'Koko',
#    'e',
#    'seu',
#    'gatinho.']),
#  ('__label__por',
#   ['Susan',
#    'consegue',
#    'dizer',
#    'à',
#    'sua',
#    'mãe',
#    'que',
#    'é',
#    'hora',
#    'de',
#    'dizer',
#    'adeus.']),
#  ('__label__tur', ['Ben', 'onu', 'dikkatle', 'dinlemeye', 'çalıştım.']),
#  ('__label__eng',
#   ['The', 'red', 'umbrella', 'reminded', 'her', 'of', 'her', 'grandma.']),
#  ('__label__eng', ['Sami', "didn't", 'wash', 'them.']),
#  ('__label__fra',
#   ['Il',
#    'a',
#    'fait',
#    'des',
#    'fautes',
#    'de',
#    'grammaire',
#    'dans',
#    'sa',
#    'dissertation.']),
#  ('__label__por', ['Só', 'compro', 'carros', 'amarelos.']),
#  ('__label__eng',
#   ['Have',
#    'you',
#    'ever',
#    'experienced',
#    'something',
#    'really',
#    'strange',
#    'which',
#    'you',
#    'can’t',
#    'really',
#    'explain',
#    'and',
#    'which,',
#    'when',
#    'you',
#    'really',
#    'think',
#    'about',
#    'it',
#    'without',
#    'ignoring',
#    'it,',
#    'it',
#    'actually',
#    'makes',
#    'you',
#    'very',
#    'frightened.']),
#  ('__label__tur',
#   ['Hükümet', 'onu', 'bütün', 'haklarından', 'mahrum', 'etti.']),
#  ('__label__ita',
#   ['Vai', 'a', 'costruire', 'negozi', 'negli', 'Stati', 'Uniti?']),
#  ('__label__rus', ['Он', 'всем', 'это', 'говорит.']),
#  ('__label__epo', ['Kion', 'precize', 'vi', 'volas', 'diri?']),
#  ('__label__rus',
#   ['Он',
#    'говорит',
#    'на',
#    'эсперанто',
#    'с',
#    'сильным',
#    'русским',
#    'акцентом.']),
#  ('__label__epo', ['Ŝi', 'ne', 'estas', 'mia', 'fratino.']),
#  ('__label__epo', ['Ĉu', 'tion', 'ni', 'povas', 'fari', 'ĉi-semajne?']),
#  ('__label__rus', ['Вы', 'очень', 'сильно', 'изменились.']),
#  ('__label__ita', ['Le', 'piacciono', 'i', 'fagioli.']),
#  ('__label__eng',
#   ['The',
#    'new',
#    'law',
#    'should',
#    'take',
#    'a',
#    'bite',
#    'out',
#    'of',
#    'organized',
#    'crime.']),
#  ('__label__por', ['Sua', 'mãe', 'está', 'sentada', 'à', 'sua', 'esquerda.']),
#  ('__label__spa', ['No', 'podía', 'ir', 'a', 'ningún', 'otro', 'sitio.']),
#  ('__label__rus', ['Подумай', 'о', 'голодающих', 'детях.']),
#  ('__label__eng',
#   ['Already',
#    'two',
#    'weeks',
#    'went',
#    'by',
#    'and',
#    'I',
#    'have',
#    'not',
#    'seen',
#    'you.']),
#  ('__label__rus', ['Мы', 'уже', 'привыкли', 'к', 'тому', 'шуму.']),
#  ('__label__eng', ['He', 'rolled', 'his', 'eyes.']),
#  ('__label__deu', ['Alle', 'meine', 'Brüder', 'sind', 'berufstätig.']),
#  ('__label__ita', ['Sicuramente', 'ci', 'sarà', "un'altra", 'occasione!']),
#  ('__label__ita',
#   ['Il', 'suo', 'colore', 'preferito', 'non', 'è', 'il', 'rosso.']),
#  ('__label__ita', ['Autocommiseriamoci', 'sempre.']),
#  ('__label__fra',
#   ['Tom', 'fait', 'la', 'navette', 'à', "l'école", 'en', 'vélo.']),
#  ('__label__hun',
#   ['Nyugalma', 'kedvezően', 'befolyásolta', 'a', 'környezetét.']),
#  ('__label__tur', ['"Kuzenlerin', 'nereli?"', '"Malta."']),
#  ('__label__ita', ['Voleva', 'che', 'lavorassi', 'di', 'più.']),
#  ('__label__rus', ['Я', 'там?']),
#  ('__label__rus',
#   ['Новые', 'предложения', 'добавлять', 'труднее,', 'чем', 'переводить.']),
#  ('__label__eng', ["Nothing's", 'going', 'my', 'way', 'today.']),
#  ('__label__fra',
#   ['Le', 'courrier', 'est-il', 'livré', 'le', 'dimanche', '?']),
#  ('__label__tur', ['Tom', 'bana', 'bir', 'şey', 'söylemeye', 'çalışıyordu.']),
#  ('__label__hun', ['Hadd', 'menjek', 'egyedül.']),
#  ('__label__deu', ['Tom', 'war', 'in', 'finanziellen', 'Schwierigkeiten.']),
#  ('__label__eng',
#   ['This', "isn't", 'the', 'first', 'time', "you've", 'been', 'late.']),
#  ('__label__rus', ['Том,', 'возможно,', 'умрёт', 'на', 'этой', 'неделе.']),
#  ('__label__hun', ['Írásfüggő', 'vagyok.']),
#  ('__label__hun', ['Jól', 'viselkedek', 'majd.']),
#  ('__label__por',
#   ['Onde',
#    'existe',
#    'corpo',
#    'de',
#    'bombeiros,',
#    'há',
#    'também',
#    'incêndios.',
#    'Isso',
#    'é',
#    'algo',
#    'totalmente',
#    'lógico.',
#    'Estou',
#    'certo?']),
#  ('__label__deu',
#   ['Diese',
#    'Regierung',
#    'wird',
#    'das',
#    'Land',
#    'in',
#    'den',
#    'Abgrund',
#    'führen.']),
#  ('__label__deu',
#   ['Einer', 'musste', 'ja', 'schließlich', 'damit', 'anfangen.']),
#  ('__label__eng', ['I', 'got', 'arrested', 'for', 'shoplifting.']),
#  ('__label__epo', ['Bonvole', 'ne', 'malŝaltu.']),
#  ('__label__rus', ['Женщина', '-', 'она', 'тоже', 'человек!']),
#  ('__label__ita', ['Tom', 'e', 'Mary', 'hanno', 'ragione.']),
#  ('__label__spa',
#   ['Deja', 'el', 'plato', 'pelado', 'o', 'no', 'tienes', 'postre.']),
#  ('__label__epo', ['Se', 'mi', 'nur', 'scius', 'lian', 'adreson.']),
#  ('__label__fra', ['Je', 'veux', 'que', 'tu', 'aies', 'ceci.']),
#  ('__label__spa',
#   ['¿Cuál', 'es', 'el', 'continente', 'más', 'poblado', 'del', 'mundo?']),
#  ('__label__hun', ['Akkor', 'osszuk', 'el', 'a', 'feladatokat!']),
#  ('__label__deu',
#   ['Trink',
#    'nicht',
#    'so',
#    'viel',
#    'Kaffee,',
#    'das',
#    'kann',
#    'dir',
#    'schaden!']),
#  ('__label__eng', ['They', 'were', 'true', 'patriots.']),
#  ('__label__rus', ['Можешь', 'одолжить', 'мне', 'один', 'доллар?']),
#  ('__label__tur',
#   ['Bu', 'sınıf', '15', 'erkekten', 've', '28', 'kızdan', 'oluşuyor.']),
#  ('__label__eng',
#   ['I',
#    "don't",
#    'want',
#    'to',
#    'have',
#    'to',
#    'hurt',
#    'you,',
#    'but',
#    'if',
#    'you',
#    'get',
#    'in',
#    'my',
#    'way,',
#    "I'll",
#    'have',
#    'no',
#    'choice.']),
#  ('__label__eng',
#   ['To',
#    'every',
#    'thing',
#    'there',
#    'is',
#    'a',
#    'season,',
#    'and',
#    'a',
#    'time',
#    'to',
#    'every',
#    'purpose.']),
#  ('__label__eng', ['Do', 'you', 'have', 'a', 'guest?']),
#  ('__label__eng',
#   ["We're",
#    'going',
#    'to',
#    'do',
#    'what',
#    'Tom',
#    'said',
#    'we',
#    'should',
#    'do.']),
#  ('__label__eng', ['He', 'looks', 'like', 'an', 'honest', 'man.']),
#  ('__label__epo',
#   ['Alvoku',
#    'Tomon',
#    'kaj',
#    'zorgu,',
#    'ke',
#    'li',
#    'estu',
#    'ĉi',
#    'tie',
#    'je',
#    'la',
#    'oka',
#    'horo',
#    'anstataŭ',
#    'je',
#    'la',
#    'deka.']),
#  ('__label__eng',
#   ['I',
#    'know',
#    'that',
#    'Tom',
#    'knows',
#    'why',
#    'I',
#    'did',
#    'that',
#    'without',
#    'him.']),
#  ('__label__eng', ["That's", 'really', 'funny.']),
#  ('__label__rus', ['Я', 'буду', 'там', 'в', 'половине', 'восьмого.']),
#  ('__label__eng',
#   ['Tom', 'may', 'be', 'able', 'to', 'answer', 'the', 'question.']),
#  ('__label__epo', ['Tomo', 'estas', 'tre', 'ambicia.']),
#  ('__label__eng', ['I', 'should', 'have', 'stayed', 'in', 'Boston.']),
#  ('__label__deu',
#   ['Ein',
#    'kranker',
#    'Mensch',
#    'sehnt',
#    'sich',
#    'sehr',
#    'nach',
#    'der',
#    'Gesundheit.',
#    'Nach',
#    'der',
#    'Genesung',
#    'neigt',
#    'der',
#    'gleiche',
#    'Mensch',
#    'dazu,',
#    'den',
#    'Wert',
#    'der',
#    'Gesundheit',
#    'zu',
#    'vergessen.']),
#  ('__label__tur', ['Hırslıyım.']),
#  ('__label__rus',
#   ['Меня',
#    'печалит,',
#    'что',
#    'ты',
#    'говоришь:',
#    '"Ты',
#    'новичок',
#    'и',
#    'всегда',
#    'им',
#    'будешь".']),
#  ('__label__epo', ['Tomo', 'povas', 'fari', 'tion', 'sen', 'mia', 'helpo.']),
#  ('__label__eng',
#   ['What', 'are', 'the', 'chances', 'of', 'that', 'happening?']),
#  ('__label__por',
#   ['Você',
#    'pensa',
#    'que,',
#    'se',
#    'as',
#    'ignorar,',
#    'as',
#    'coisas',
#    'desagradáveis',
#    'desaparecem?']),
#  ('__label__eng',
#   ['Tom',
#    'asked',
#    'if',
#    'there',
#    'was',
#    'still',
#    'a',
#    'police',
#    'car',
#    'parked',
#    'outside.']),
#  ('__label__spa',
#   ['Visto',
#    'desde',
#    'el',
#    'cielo,',
#    'el',
#    'río',
#    'se',
#    'parecía',
#    'a',
#    'una',
#    'enorme',
#    'serpiente.']),
#  ('__label__hun', ['Tom', 'a', 'járda', 'mellett', 'sétált.']),
#  ('__label__tur',
#   ['Belirsiz',
#    'ifadeler',
#    'genellikle',
#    'eğlenceli',
#    'yorumlara',
#    'yol',
#    'açar.']),
#  ('__label__tur',
#   ['Saatimi',
#    'kaybettim,',
#    'bu',
#    'yüzden',
#    'bir',
#    'tane',
#    'almak',
#    'zorundayım.']),
#  ('__label__epo',
#   ['Mi',
#    'bedaŭras,',
#    'sed',
#    'mia',
#    'ĉefo',
#    'nun',
#    'dormantas.',
#    'Bonvolu',
#    'reveni',
#    'morgaŭ.']),
#  ('__label__tur',
#   ['"İyi',
#    'Fransızca',
#    'biliyorsun"',
#    '"Senin',
#    'kadar',
#    'akıcı',
#    'değilim."']),
#  ('__label__eng', ["Don't", 'make', 'me', 'lose', 'my', 'patience.']),
#  ('__label__eng', ['We', 'could', 'talk', 'about', 'her.']),
#  ('__label__eng', ['Tom', 'has', 'to', 'change', 'his', 'shirt.']),
#  ('__label__rus', ['Я', 'могу', 'помочь', 'Тому', 'это', 'сделать.']),
#  ('__label__tur', ['Okulda', 'birlikteyiz.']),
#  ('__label__fra', ['Ils', "l'embauchèrent."]),
#  ('__label__tur', ['Onunla', 'iyi', 'geçinirim.']),
#  ('__label__eng', ['Layla', 'should', 'serve', 'dinner', 'now.']),
#  ('__label__spa', ['No', 'me', 'puedo', 'llevar', 'bien', 'con', 'él.']),
#  ('__label__tur', ['Tombul', 'olabilirim', 'ama', 'dinçim.']),
#  ('__label__por', ['O', 'amor', 'sempre', 'vence', 'no', 'fim.']),
#  ('__label__eng', ['Tom', 'has', 'been', 'like', 'father', 'to', 'me.']),
#  ('__label__rus', ['Я', 'приеду', 'во', 'вторник.']),
#  ('__label__por', ['O', 'João', 'foi', 'condenado', 'por', 'corrupção.']),
#  ('__label__rus', ['Нам', 'надо', 'помыть', 'машину.']),
#  ('__label__eng',
#   ['You',
#    'should',
#    'consider',
#    'the',
#    'problem',
#    'before',
#    'coming',
#    'to',
#    'a',
#    'decision.']),
#  ('__label__tur', ['Sadece', 'bunun', 'incitmediğini', 'söyleyelim.']),
#  ('__label__spa', ['Su', 'dormitorio', 'queda', 'aquí', 'arriba.']),
#  ('__label__ita', ['Ecco', 'perché', 'era', 'stato', 'indicato!']),
#  ('__label__epo', ['Kostete', 'aĉetu,', 'kostege', 'vendu!']),
#  ('__label__ita', ['Ci', 'guardammo.']),
#  ('__label__por',
#   ['Tom', 'mostrou', 'uma', 'imagem', 'de', 'John', 'a', 'Maria.']),
#  ('__label__rus', ['Ваш', 'приятель', 'вот-вот', 'придёт.']),
#  ('__label__fra', ['Il', 'était', 'dans', 'le', 'besoin.']),
#  ('__label__ita',
#   ['"Dove', 'vanno', 'in', 'vacanza?"', '"Negli', 'Stati', 'Uniti."']),
#  ('__label__ita', ['Lui', 'cercò', 'di', 'suicidarsi.']),
#  ('__label__fra',
#   ['Les',
#    'habitants',
#    'furent',
#    'frappés',
#    "d'une",
#    'durable',
#    'sécheresse.']),
#  ('__label__ita',
#   ['Sono', 'contento', 'che', 'ti', 'piaccia', 'la', 'frase.']),
#  ('__label__tur',
#   ['Onlar', "Tom'un", "Brezilya'ya", 'geldiğini', 'söylüyorlar.']),
#  ('__label__tur', ['O', 'değişmek', 'üzere.']),
#  ('__label__deu',
#   ['Bist', 'du', 'mit', 'dem', 'Klammerbeutel', 'gepudert', 'worden?']),
#  ('__label__eng', ['We', 'brought', 'ours.']),
#  ('__label__eng',
#   ['Tom', "isn't", 'sure', 'Mary', 'has', 'to', 'do', 'that.']),
#  ('__label__spa',
#   ['Él', 'hace', 'que', 'todo', 'el', 'mundo', 'se', 'sienta', 'cómodo.']),
#  ('__label__rus', ['Я', 'не', 'знаю', 'никого', 'с', 'таким', 'именем.']),
#  ('__label__eng',
#   ['I',
#    'inquired',
#    'whether',
#    'the',
#    'plane',
#    'would',
#    'arrive',
#    'on',
#    'time.']),
#  ('__label__spa', ['Tengo', 'una', 'sorpresa', 'para', 'ti.']),
#  ('__label__ita', ['Leggere', 'un', 'libro', 'è', 'interessante.']),
#  ('__label__tur', ['Bunu', 'yaptığını', 'itiraf', 'etmeye', 'zorladık.']),
#  ('__label__deu', ['Er', 'tauchte', 'kopfüber', 'ins', 'Wasser.']),
#  ('__label__tur',
#   ['Tom,',
#    "Mary'nin",
#    'neye',
#    'ihtiyacı',
#    'olduğunu',
#    'biliyor',
#    'gibi',
#    'görünmüyor.']),
#  ('__label__ita', ['Loro', 'non', 'mi', 'hanno', 'capita.']),
#  ('__label__fra', ['Êtes-vous', 'des', 'malades', 'mentaux', '?']),
#  ('__label__eng', ['We', 'sent', 'for', 'a', 'doctor.']),
#  ('__label__deu',
#   ['Wegen',
#    'seiner',
#    'früheren',
#    'Engagements',
#    'konnte',
#    'er',
#    'nicht',
#    'an',
#    'der',
#    'Veranstaltung',
#    'teilnehmen.']),
#  ('__label__eng', ['Mary', 'told', 'me', 'she', "wasn't", 'ticklish.']),
#  ('__label__eng', ['Tom', 'said', 'that', 'he', 'was', 'extremely', 'tired.']),
#  ('__label__rus', ['Этого', 'не', 'могло', 'быть.']),
#  ('__label__deu',
#   ['Ich', 'falle', 'gleich', 'um,', 'so', 'müde', 'bin', 'ich.']),
#  ('__label__spa', ['¿Estás', 'listo', 'para', 'empezar?']),
#  ('__label__eng',
#   ['Sami',
#    'wanted',
#    'to',
#    'find',
#    'nice',
#    'things',
#    'to',
#    'say',
#    'to',
#    'Layla.']),
#  ('__label__epo', ['Ĉiuj', 'lacertoj', 'povas', 'ellasi', 'ovojn.']),
#  ('__label__epo',
#   ['Fiksi',
#    'celojn',
#    'por',
#    'la',
#    'trejnado',
#    'povas',
#    'esti',
#    'ruza',
#    'ideokaj',
#    'por',
#    'la',
#    'motivado',
#    'kaj',
#    'por',
#    'antaŭenpeli',
#    'sin',
#    'ekstran',
#    'iometon.']),
#  ('__label__fra', ['Je', 'tremble.']),
#  ('__label__spa', ['Hay', 'una', 'moneda', 'de', 'oro.']),
#  ('__label__rus', ['Живи', 'до', 'ста', 'лет!']),
#  ('__label__por', ['Ele', 'não', 'queria', 'desapontar', 'a', 'mãe.']),
#  ('__label__fra',
#   ['Je', 'ne', 'connais', 'en', 'réalité', 'pas', 'la', 'réponse.']),
#  ('__label__eng',
#   ['Knowledge',
#    'is',
#    'like',
#    'manure,',
#    "it's",
#    'only',
#    'good',
#    'when',
#    'spread.']),
#  ('__label__spa', ['¡No', 'me', 'moleste!']),
#  ('__label__por',
#   ['O', 'Paul', 'se', 'veste', 'de', 'forma', 'bem', 'chique.']),
#  ('__label__ita', ['Puoi', 'sbrigarti?']),
#  ('__label__epo', ['Vi', 'ne', 'rajtas', 'rezigni.']),
#  ('__label__rus',
#   ['Том', 'сказал,', 'что', 'не', 'хочет', 'больше', 'ждать.']),
#  ('__label__por', ['Ele', 'é', 'alérgico', 'a', 'alguma', 'planta?']),
#  ('__label__eng', ['Now,', "it's", 'my', 'turn', 'to', 'laugh.']),
#  ('__label__eng',
#   ["Didn't", 'you', 'know', 'that', 'Tom', 'would', 'be', 'here?']),
#  ('__label__deu', ['Sie', 'müssen', 'auf', 'alles', 'gefasst', 'sein.']),
#  ('__label__eng',
#   ['Mary',
#    'expected',
#    'Tom',
#    'to',
#    'wink',
#    'at',
#    'her,',
#    'but',
#    'he',
#    "didn't."]),
#  ('__label__fra',
#   ['Je',
#    'comprends',
#    'ce',
#    'que',
#    'vous',
#    'dites,',
#    'mais',
#    'je',
#    'ne',
#    'suis',
#    'pas',
#    'du',
#    'même',
#    'avis',
#    'que',
#    'vous.']),
#  ('__label__epo',
#   ['Tiun',
#    'ĉi',
#    'transakcion',
#    'oni',
#    'kondukis',
#    'en',
#    'enoj,',
#    'ne',
#    'en',
#    'usonaj',
#    'dolaroj.']),
#  ('__label__rus', ['Вам', 'надо', 'было', 'оставить', 'их', 'в', 'покое.']),
#  ('__label__spa',
#   ['No', 'puedo', 'distinguir', 'el', 'violeta', 'del', 'rojo.']),
#  ('__label__rus', ['Битый', 'небитого', 'везёт.']),
#  ('__label__eng',
#   ['The',
#    'relationship',
#    'is',
#    'on',
#    'the',
#    'rocks',
#    'and',
#    'the',
#    'couple',
#    'seems',
#    'unable',
#    'to',
#    'find',
#    'ways',
#    'to',
#    'resolve',
#    'their',
#    'differences.']),
#  ('__label__eng',
#   ['If',
#    'Mary',
#    "isn't",
#    'here',
#    'by',
#    '2:30,',
#    'she',
#    'probably',
#    "won't",
#    'come',
#    'at',
#    'all.']),
#  ('__label__eng',
#   ["I've", 'always', 'thought', 'you', 'knew', 'how', 'to', 'swim.']),
#  ('__label__epo',
#   ['Ĉu', 'vi', 'deziras', 'aŭskulti', 'min', 'dum', 'kelkaj', 'minutoj?']),
#  ('__label__ita', ['La', 'trovò', 'molto', 'importante.']),
#  ('__label__eng',
#   ["Newton's",
#    'law',
#    'of',
#    'gravity',
#    'is',
#    'a',
#    'mathematical',
#    'description',
#    'of',
#    'the',
#    'way',
#    'bodies',
#    'are',
#    'observed',
#    'to',
#    'attract',
#    'one',
#    'another,',
#    'based',
#    'on',
#    'many',
#    'scientific',
#    'experiments',
#    'and',
#    'observations.']),
#  ('__label__eng', ['Tom', "didn't", 'seem', 'ruffled', 'at', 'all.']),
#  ('__label__spa', ['Predicar', 'agota', 'el', 'cuerpo.']),
#  ('__label__ita', ['Noi', 'dovremmo', 'continuare', 'ad', 'aiutare', 'Tom.']),
#  ('__label__epo', ['Marcipanporkoj', 'ne', 'gruntas.']),
#  ('__label__ita', ['Non', 'so', 'nulla', 'di', 'lui.']),
#  ('__label__deu', ['Tom', 'wollte', 'nicht', 'davon', 'ablassen.']),
#  ('__label__ita',
#   ['Tom', 'ha', 'detto', 'che', 'voleva', 'andarsene', 'da', 'Boston.']),
#  ('__label__ita',
#   ['Visto',
#    'che',
#    'devi',
#    'andare',
#    'al',
#    'supermercato,',
#    'già',
#    'che',
#    'ci',
#    'sei',
#    'compra',
#    'anche',
#    'delle',
#    'uova.']),
#  ('__label__deu', ['Tom', 'ist', 'eine', 'familienorientierte', 'Person.']),
#  ('__label__rus',
#   ['В', 'чашке', 'трещина,', 'поэтому', 'содержимое', 'протекает.']),
#  ('__label__fra',
#   ['Ce', "n'est", 'pas', 'comme', 'cela', "qu'il", 'fonctionne.']),
#  ('__label__ita', ['Taci', 'un', "po'!"]),
#  ('__label__eng', ['She', 'painted', 'her', 'room', 'white.']),
#  ('__label__hun', ['Sok', 'szerencsét', 'a', 'vizsgádhoz!']),
#  ('__label__deu',
#   ['Immer',
#    'weniger',
#    'Polen',
#    'möchten',
#    'als',
#    'Erdbeerpflücker',
#    'arbeiten.']),
#  ('__label__hun',
#   ['Ha', 'olyan', 'sokat', 'eszel,', 'fájni', 'fog', 'a', 'gyomrod.']),
#  ('__label__rus',
#   ['Женщины',
#    'в',
#    'джинсах',
#    'с',
#    'завышенной',
#    'талией',
#    'выглядят',
#    'как',
#    'волк',
#    'из',
#    '"Ну,',
#    'погоди!".']),
#  ('__label__eng', ['They', 'said', 'they', 'need', 'to', 'do', 'that.']),
#  ('__label__eng', ['We', 'managed', 'to', 'swim', 'across', 'the', 'river.']),
#  ('__label__eng', ['Sami', 'was', 'close', 'to', 'Layla.']),
#  ('__label__eng', ['Sami', 'likes', 'anime', 'porn.']),
#  ('__label__spa', ['¿Es', 'esto', 'normal?']),
#  ('__label__eng', ['Have', 'you', 'called', 'him', 'yet?']),
#  ('__label__rus', ['Твой', 'учебник', 'на', 'полу.']),
#  ('__label__rus', ['Они', 'отправились', 'на', 'поиски', 'сокровищ.']),
#  ('__label__por', ['Maria', 'foi', 'expulsa', 'do', 'colégio.']),
#  ('__label__spa', ['Tom', 'pasa', 'mucho', 'tiempo', 'en', 'el', 'teléfono.']),
#  ('__label__eng', ['Please', 'show', 'me', 'around', 'Boston.']),
#  ('__label__rus', ['Твоя', 'жена', 'говорит', 'по-английски?']),
#  ('__label__epo', ['Bonvolu', 'kuraci', 'lin', 'per', 'fluorido.']),
#  ('__label__ita', ['Ero', 'preoccupata', 'per', 'lei.']),
#  ('__label__eng',
#   ['My', 'pet', 'raccoon', 'can', 'type', 'faster', 'than', 'you.']),
#  ('__label__eng', ['Tom', "isn't", 'skeptical,', 'but', 'Mary', 'is.']),
# ...
#   ['Io', 'la', 'incontro', 'a', 'scuola', 'di', 'tanto', 'intanto.']),
#  ('__label__tur', ['Son', 'bir', 'sorum', 'var.']),
#  ('__label__eng', ['Make', 'any', 'arrangements', 'you', 'like.']),
#  ('__label__eng', ['She', 'observed', 'how', 'butterflies', 'fly.']),
#  ('__label__eng',
#   ['I',
#    'thought',
#    'that',
#    'we',
#    'had',
#    'three',
#    'weeks',
#    'to',
#    'finish',
#    'this',
#    'job.']),
#  ('__label__eng', ['It', "hasn't", 'been', 'easy', 'for', 'her.']),
#  ('__label__eng', ['I', "can't", 'study', 'with', 'you', 'watching', 'me.']),
#  ('__label__rus', ['Я', 'не', 'могу', 'защитить', 'Тома.']),
#  ('__label__epo', ['Remu', 'plu!']),
#  ('__label__eng',
#   ['Please', 'make', 'a', 'sentence', 'by', 'using', 'this', 'word.']),
#  ('__label__eng', ['Tom', "isn't", 'good', 'at', 'speaking', 'French.']),
#  ('__label__eng', ["I've", 'got', 'lost', 'in', 'the', 'forest.']),
#  ('__label__spa',
#   ['No',
#    'sé',
#    'cuándo',
#    'vendrá,',
#    'pero',
#    'cuando',
#    'lo',
#    'haga,',
#    'lo',
#    'hará',
#    'lo',
#    'mejor',
#    'que',
#    'pueda.']),
#  ('__label__eng', ['We', 'saved', 'you', 'a', 'seat.']),
#  ('__label__epo', ['Kie', 'Tomo', 'estis', 'torturita?']),
#  ('__label__ita', ['Si', 'sarebbe', 'buttato.']),
#  ('__label__eng', ['Does', 'Tom', 'wear', 'boots?']),
#  ('__label__eng',
#   ['I',
#    'hope',
#    'you',
#    "don't",
#    'expect',
#    'me',
#    'to',
#    'do',
#    'that',
#    'for',
#    'you.']),
#  ('__label__rus', ['Вы', 'проспали', 'и', 'опоздали', 'в', 'школу.']),
#  ('__label__spa',
#   ['Trae', 'el', 'gato,', 'necesito', 'levantar', 'el', 'coche.']),
#  ('__label__eng', ['This', 'is', 'an', 'emergency', 'broadcast!']),
#  ('__label__por',
#   ['Estamos', 'com', 'alguns', 'convidados', 'essa', 'noite.']),
#  ('__label__hun', ['Nem', 'látom', 'semmi', 'okát.']),
#  ('__label__eng', ['They', 'guarantee', 'this', 'clock', 'for', 'a', 'year.']),
#  ('__label__fra', ['Sont-ils', 'vraiment', 'amis', '?']),
#  ('__label__eng',
#   ['The',
#    'wind',
#    'blew',
#    'so',
#    'strongly',
#    'today,',
#    'that',
#    'a',
#    'tree',
#    'was',
#    'knocked',
#    'over.']),
#  ('__label__rus', ['Я', 'думал,', 'Том', 'беспокоится.']),
#  ('__label__eng', ['Are', 'you', 'still', 'going', 'to', "Tom's", 'party?']),
#  ('__label__hun',
#   ['Tudod,', 'hogy', 'nem', 'szeretem', 'a', 'karalábélevest!']),
#  ('__label__tur',
#   ["Tom'un", 'en', 'sevdiği', 'film', '"Brokeback', 'Mountain"dır.']),
#  ('__label__deu', ['Zeig', 'mir,', 'was', 'du', 'hast!']),
#  ('__label__eng',
#   ['The', 'moment', 'I', 'arrived', 'home,', 'I', 'went', 'to', 'bed.']),
#  ('__label__eng', ['Do', 'you', 'like', 'small', 'sausages?']),
#  ('__label__fra', ["J'ai", 'souvent', 'envie', "d'aller", 'là-bas.']),
#  ('__label__spa', ['No', 'sabíamos', 'qué', 'autobús', 'tomar.']),
#  ('__label__por', ['Que', 'pechincha!']),
#  ('__label__eng', ["I'm", 'game.']),
#  ('__label__tur',
#   ['Tanrı',
#    'bile',
#    'hata',
#    'yaptı',
#    've',
#    'biz',
#    'günahkar',
#    'kullarını',
#    'yarattı.']),
#  ('__label__eng', ['Tom', 'recognized', 'her', 'handwriting.']),
#  ('__label__deu',
#   ['Was', 'für', 'Gemüse', 'bauen', 'Sie', 'gewöhnlich', 'an?']),
#  ('__label__epo', ['Ie', 'ajn', 'oni', 'devas', 'meti', 'linion.']),
#  ('__label__tur',
#   ['Tom', "Mary'nin", 'onun', 'hakkında', 'söylediklerine', 'aldırmıyor.']),
#  ('__label__ita', ['Lui', 'ama', 'il', 'jazz,', 'e', "anch'io."]),
#  ('__label__ita', ['Tom', 'vive', 'qua', 'adesso,', 'vero?']),
#  ('__label__spa', ['Ella', 'tiene', 'el', 'ojo', 'derecho', 'ciego.']),
#  ('__label__deu', ['Gestern', 'haben', 'wir', 'die', 'Wand', 'geweißt.']),
#  ('__label__rus',
#   ['Самые', 'строгие', 'судьи', 'для', 'человека', '—', 'его', 'дети.']),
#  ('__label__epo', ['Vi', 'ne', 'estas', 'amuza.']),
#  ('__label__fra', ['Nous', 'sommes', 'accoudées.']),
#  ('__label__eng', ['Where', 'are', 'the', 'luggage', 'carts?']),
#  ('__label__por', ['Nós', 'adiamos', 'o', 'evento.']),
#  ('__label__rus', ['Она', 'из', 'дерева', 'или', 'из', 'металла?']),
#  ('__label__ita', ['Quella', 'sarta', 'è', 'bravissima.']),
#  ('__label__ita', ['Tom', 'ha', 'molti', 'talenti.']),
#  ('__label__tur', ['Tom', 'sadece', 'yürümeye', 'devam', 'etti.']),
#  ('__label__eng', ["I've", 'got', 'longer', 'legs', 'than', 'her.']),
#  ('__label__por',
#   ['Os',
#    'alunos',
#    'têm',
#    'trinta',
#    'e',
#    'duas',
#    'horas',
#    'de',
#    'aula',
#    'por',
#    'semana.']),
#  ('__label__epo', ['Ĉio', 'ĉi', 'ŝanĝiĝos.']),
#  ('__label__epo',
#   ['Larmoj', 'fluis', 'malsupren', 'sur', 'la', 'vangoj', 'de', 'Alica.']),
#  ('__label__epo', ['Mi', 'volas', 'dividi', 'mian', 'vivon', 'kun', 'vi.']),
#  ('__label__ita', ['Quando', 'partiranno', 'per', 'Vienna?']),
#  ('__label__eng', ['I', 'wish', 'I', 'could', 'come', 'too.']),
#  ('__label__por',
#   ['Você',
#    'realmente',
#    'não',
#    'se',
#    'importa',
#    'que',
#    'eu',
#    'esteja',
#    'indo',
#    'sozinho?']),
#  ('__label__fra',
#   ["J'aimerais", 'votre', 'permission', 'pour', "l'employer."]),
#  ('__label__eng',
#   ['He', 'will', 'be', 'playing', 'tennis', 'tomorrow', 'afternoon.']),
#  ('__label__eng',
#   ['If', 'the', 'weather', 'is', 'nice,', "I'll", 'go', 'swimming.']),
#  ('__label__tur',
#   ['Tom', 'bu', 'mahallede', 'bir', 'ev', 'satın', 'almak', 'istiyor.']),
#  ('__label__eng',
#   ['There', 'are', 'beautiful', 'flowers', 'in', 'the', 'garden.']),
#  ('__label__fra',
#   ['Chacune', 'de', 'ses', 'chansons', 'était', 'un', 'tube.']),
#  ('__label__eng', ['I', 'saw', 'her', 'take', 'your', 'keys.']),
#  ('__label__ita', ['"Dove', 'andate', 'in', 'vacanza?"', '"In', 'Corea."']),
#  ('__label__tur', ['Peki', 'bunu', 'nasıl', 'yapabiliriz?']),
#  ('__label__epo',
#   ['Miaopinie', 'vi', 'ja', 'scias,', 'ke', 'mi', 'ŝatas', 'vin.']),
#  ('__label__eng',
#   ['Tom',
#    'showed',
#    'me',
#    'a',
#    'picture',
#    'of',
#    'the',
#    'food',
#    'they',
#    'had',
#    'eaten.']),
#  ('__label__hun',
#   ['Folyton', 'ez', 'a', 'probléma', 'jár', 'az', 'eszemben.']),
#  ('__label__tur',
#   ['Belki',
#    'de',
#    'geceleyin',
#    'oraya',
#    'o',
#    'kadar',
#    'geç',
#    'gitmemem',
#    'gerekirdi.']),
#  ('__label__tur', ['Tom', 'bir', 'silah', 'kaptı.']),
#  ('__label__epo',
#   ['La',
#    'patrino',
#    'kaj',
#    'la',
#    'filino',
#    'reprezentis',
#    'du',
#    'generaciojn.']),
#  ('__label__eng', ['I', 'rushed', 'Tom', 'to', 'the', 'hospital.']),
#  ('__label__eng',
#   ['I', 'assume', 'that', 'Tom', 'is', 'up', 'to', 'no', 'good.']),
#  ('__label__ita', ['Tre', 'bambine', 'stavano', 'giocando', 'nel', 'parco.']),
#  ('__label__rus', ['Уверен,', 'что', 'Том', 'вас', 'не', 'ненавидит.']),
#  ('__label__eng',
#   ['I',
#    'know',
#    'that',
#    'Tom',
#    'and',
#    'Mary',
#    'both',
#    'want',
#    'to',
#    'do',
#    'that.']),
#  ('__label__eng', ["We'll", 'still', 'do', 'that.']),
#  ('__label__fra', ['Je', 'ne', 'les', 'tords', 'pas.']),
#  ('__label__eng',
#   ["I've", 'been', 'thinking', 'about', 'what', 'we', 'need', 'to', 'do.']),
#  ('__label__epo', ['Via', 'grandiozo', 'laboro', 'hontigas', 'min.']),
#  ('__label__eng', ["You're", 'in', 'love.']),
#  ('__label__epo',
#   ['Laŭdire',
#    'en',
#    'Usono',
#    'minimume',
#    '216',
#    'milionoj',
#    'da',
#    'pafarmiloj',
#    'estas',
#    'en',
#    'privata',
#    'posedo.']),
#  ('__label__deu', ['Du', 'bist', 'immer', 'beschäftigt.']),
#  ('__label__tur',
#   ['Doğum',
#    'kontrolü',
#    'için',
#    'bir',
#    'prezervatif',
#    'kullandın,',
#    'değil',
#    'mi?']),
#  ('__label__eng',
#   ['Tom',
#    "didn't",
#    'tell',
#    'Mary',
#    'he',
#    "didn't",
#    'intend',
#    'to',
#    'do',
#    'that.']),
#  ('__label__deu',
#   ['Tom', 'wohnt', 'in', 'einem', 'wohnlichen', 'Haus', 'am', 'Strand.']),
#  ('__label__rus', ['Тому', 'нужно', 'лекарство.']),
#  ('__label__eng',
#   ['I',
#    'saw',
#    'Tom',
#    'walking',
#    'in',
#    'the',
#    'park',
#    'with',
#    'Mary',
#    'last',
#    'Monday.']),
#  ('__label__eng', ['Tom', "wasn't", 'working', 'part-time.']),
#  ('__label__fra', ['Ils', 'le', 'laissèrent', 'pour', 'mort.']),
#  ('__label__eng', ['Tom', "isn't", 'funny', 'either.']),
#  ('__label__rus', ['Нас', 'связывает', 'тесная', 'дружба.']),
#  ('__label__tur', ['Bu', 'kano', 'güvenli', 'değil.']),
#  ('__label__rus',
#   ['Что', 'будет', 'с', 'его', 'детьми', 'после', 'его', 'смерти?']),
#  ('__label__deu', ['Was', 'Tom', 'getan', 'hat,', 'war', 'illegal.']),
#  ('__label__rus', ['Я', 'не', 'знаю,', 'как', 'им', 'пользоваться.']),
#  ('__label__ita',
#   ['Quelle', 'posizioni', 'estreme', 'non', 'sono', 'compatibili.']),
#  ('__label__epo', ['Ne', 'forgesu', 'nin.']),
#  ('__label__rus', ['Ты', 'очень', 'способная.']),
#  ('__label__eng',
#   ['They', 'told', 'me', 'they', 'were', 'ready', 'to', 'do', 'that.']),
#  ('__label__eng', ["They're", 'in', 'the', 'science', 'lab.']),
#  ('__label__spa', ['No', 'soporto', 'el', 'golf.']),
#  ('__label__deu', ['Tom', 'verdient', 'Bewunderung.']),
#  ('__label__eng', ['The', 'new', 'iPads', 'look', 'amazing.']),
#  ('__label__ita', ['Un', "po'", 'gli', 'si', 'avvicina.']),
#  ('__label__tur', ['Tom', "Mary'yi,", 'ona', 'bakarken', 'yakaladı.']),
#  ('__label__tur', ['Bu', 'parayla', 'ne', 'yapmam', 'gerekiyor?']),
#  ('__label__ita', ['Queste', 'sono', 'domande', 'difficili.']),
#  ('__label__por',
#   ['Com',
#    'efeito,',
#    'o',
#    'campo',
#    'é',
#    'pequeno',
#    'mas',
#    'grande',
#    'é',
#    'o',
#    'trabalho.']),
#  ('__label__ita', ['Tom', 'era', 'un', 'eroe', 'di', 'guerra.']),
#  ('__label__eng', ['Sami', 'wore', 'a', 'blue', 'shirt.']),
#  ('__label__deu',
#   ['Überhaupt',
#    'ist',
#    'es',
#    'für',
#    'den',
#    'Forscher',
#    'ein',
#    'guter',
#    'Morgensport,',
#    'täglich',
#    'vor',
#    'dem',
#    'Frühstück',
#    'eine',
#    'Lieblingshypothese',
#    'einzustampfen,',
#    'das',
#    'erhält',
#    'jung.']),
#  ('__label__eng', ['I', 'was', 'speechless', 'with', 'emotion.']),
#  ('__label__ita',
#   ["L'insegnante", 'si', 'è', 'meravigliata', 'della', 'mia', 'risposta.']),
#  ('__label__rus', ['Я', 'живу', 'довольно', 'близко', 'от', 'Тома.']),
#  ('__label__deu', ['Ist', 'das', 'Ihre', 'erste', 'Untersuchung?']),
#  ('__label__fra', ['Nous', 'sommes', 'normales.']),
#  ('__label__eng', ['We', 'help', 'resolve', 'disputes.']),
#  ('__label__eng', ['Queen', 'Marie', 'Antoinette', 'was', 'guillotined.']),
#  ('__label__tur', ['Sahne', 'yönetimi', 'ne', 'önerir?']),
#  ('__label__rus', ['Ты', 'не', 'написал', 'ей', 'письмо?']),
#  ('__label__rus', ['Я', 'не', 'разбираюсь', 'в', 'физике.']),
#  ('__label__epo',
#   ['La', 'vivo', 'ŝajnas', 'al', 'ŝi', 'peza', 'kaj', 'senmorgaŭa.']),
#  ('__label__ita', ['Il', 'tempo', 'scorre', 'rapidamente.']),
#  ('__label__eng', ['Tom', 'received', 'a', 'phone', 'call', 'from', 'Mary.']),
#  ('__label__deu',
#   ['Tom', 'beantwortete', 'die', 'Fragen', 'der', 'Lehrerin.']),
#  ('__label__tur', ['Bu', 'mükemmel', 'bir', 'fikir', 'gibi', 'görünüyor.']),
#  ('__label__epo', ['Ŝajnas', 'neeble,', 'ĉu', 'ne?']),
#  ('__label__eng',
#   ['How', 'did', 'Tom', 'know', 'which', 'book', 'Mary', "hadn't", 'read?']),
#  ('__label__epo', ['Jes,', 'sed', 'ankaŭ', 'por', 'mi', 'estis', 'agrable.']),
#  ('__label__eng',
#   ['Tom', 'probably', "didn't", 'even', 'know', 'about', 'it.']),
#  ('__label__deu',
#   ['Wenn',
#    'er',
#    'zehn',
#    'von',
#    'zehn',
#    'in',
#    'der',
#    'Prüfung',
#    'hatte,',
#    'dann,',
#    'weil',
#    'er',
#    'betrogen',
#    'hat.']),
#  ('__label__eng',
#   ['Mary', 'lied', 'to', 'Tom', 'about', 'what', 'she', 'did.']),
#  ('__label__eng',
#   ['Tom',
#    'is',
#    'probably',
#    'not',
#    'going',
#    'to',
#    'do',
#    'that',
#    'very',
#    'well.']),
#  ('__label__fra', ['Je', 'vous', 'ai', 'vu', 'au', 'parc,', 'hier.']),
#  ('__label__epo', ['Oni', 'ne', 'permesos', 'ĝin.']),
#  ('__label__deu',
#   ['Sie', 'hat', 'vor,', 'das', 'ganze', 'Land', 'zu', 'bereisen.']),
#  ('__label__epo',
#   ['La', 'kutimo', 'pasis', 'de', 'unu', 'generacio', 'al', 'alia.']),
#  ('__label__rus', ['Могла', 'бы', 'меня', 'спросить.']),
#  ('__label__rus', ['Ты', 'хочешь', 'купить', 'утку?']),
#  ('__label__fra',
#   ['Posons', 'la', 'question', 'au', 'garçon', 'qui', 'habite', 'à', 'côté.']),
#  ('__label__eng', ['Tom', 'often', 'borrows', 'books', 'from', 'me.']),
#  ('__label__epo', ['Kion', 'vi', 'pensas?', 'Ĉu', 'tio', 'estas', 'vera?']),
#  ('__label__ita', ['Come', 'ha', 'avuto', 'il', 'mio', 'numero?']),
#  ('__label__eng', ['We', 'deserve', 'this.']),
#  ('__label__hun', ['Ez', 'kinek', 'a', 'biciklije?']),
#  ('__label__eng',
#   ['I', 'wish', 'I', 'knew', 'how', 'to', 'play', 'the', 'trombone.']),
#  ('__label__eng', ['Sami', 'only', 'made', 'six', 'dollars', 'an', 'hour.']),
#  ('__label__rus',
#   ['Народа',
#    'мудрость',
#    'не',
#    'приемлет',
#    'звона,',
#    'лишь',
#    'мысль',
#    'вождя',
#    'всегда',
#    'бывает',
#    'гласной',
#    'и,',
#    'превратившись',
#    'в',
#    'колокол',
#    'закона,',
#    'желает',
#    'истиною',
#    'стать',
#    'всевластной.']),
#  ('__label__spa', ['Me', 'lo', 'dieron.']),
#  ('__label__deu', ['Spielen', 'Sie', 'hier', 'kein', 'Baseball.']),
#  ('__label__ita', ['È', 'perduto.']),
#  ('__label__rus', ['Том', 'этого', 'не', 'сделал?']),
#  ('__label__tur',
#   ['Jody', 'sanki', 'bir', 'hayalet', 'görmüş', 'gibi', 'görünüyor.']),
#  ('__label__spa',
#   ['Mercurio',
#    'es',
#    'el',
#    'planeta',
#    'más',
#    'pequeño',
#    'de',
#    'nuestro',
#    'sistema',
#    'solar.']),
#  ('__label__spa',
#   ['Es',
#    'la',
#    'primera',
#    'vez',
#    'que',
#    'le',
#    'presto',
#    'dinero',
#    'a',
#    'Mary.']),
#  ('__label__rus', ['Том', 'не', 'был', 'хорошим', 'студентом.']),
#  ('__label__hun', ['Nincs', 'szükségem', 'az', 'engedélyedre.']),
#  ('__label__eng', ['Tom', "can't", 'believe', 'how', 'dense', 'Mary', 'is.']),
#  ('__label__rus', ['Ты', 'держался', 'молодцом.']),
#  ('__label__fra',
#   ['Aux',
#    'États-Unis',
#    "d'Amérique,",
#    'il',
#    'existe',
#    'des',
#    'syndromes',
#    'collectifs',
#    'qui',
#    "n'existent",
#    'pas',
#    'ailleurs,',
#    'comme',
#    'par',
#    'exemple',
#    "l'«",
#    'Abus',
#    'Rituel',
#    'Satanique',
#    '»',
#    'ou',
#    "l'«",
#    'enlèvement',
#    'par',
#    'des',
#    'extra-terrestres',
#    '»',
#    'et',
#    'qui',
#    'ne',
#    'sont',
#    '«',
#    'révélés',
#    '»',
#    'que',
#    'sous',
#    'hypnose.']),
#  ('__label__deu',
#   ['Das',
#    'Schicksal',
#    'verbessert',
#    'manche',
#    'Fehler',
#    'an',
#    'uns,',
#    'welche',
#    'die',
#    'Vernunft',
#    'nicht',
#    'verbessern',
#    'könnte.']),
#  ('__label__epo',
#   ['Se',
#    'vi',
#    'ne',
#    'povas',
#    'esti',
#    'io',
#    'bona',
#    'por',
#    'iu,',
#    'vi',
#    'prefere',
#    'estu',
#    'malhelpo,',
#    'ol',
#    'esti',
#    'nenio.']),
#  ('__label__tur',
#   ['Dün', 'Tom', 'bana', 'yüzmeyi', 'bilmediğini', 'söyledi.']),
#  ('__label__spa',
#   ['Muchos',
#    'leones',
#    'se',
#    'lesionan,',
#    'mientras',
#    'que',
#    'luchan',
#    'por',
#    'la',
#    'hembra.']),
#  ('__label__eng', ['I', 'suspect', 'Tom', 'has', 'to', 'do', 'that.']),
#  ('__label__tur',
#   ["Amsterdam'da",
#    'belediye',
#    'başkanları,',
#    'kadınlar',
#    'gününde',
#    'seçilir.']),
#  ('__label__rus',
#   ['Ты', 'отдаёшь', 'себе', 'отчёт', 'в', 'том,', 'что', 'это', 'значит?']),
#  ('__label__deu', ['Wir', 'haben', 'uns', 'nie', 'gesehen.']),
#  ('__label__eng', ['Mary', 'stroked', "Kate's", 'hair.']),
#  ('__label__spa', ['Voy', 'a', 'su', 'casa.']),
#  ('__label__epo', ['Ĉu', 'vi', 'ŝatas', 'la', 'basbalon,', 'Bin?']),
#  ('__label__rus', ['Моему', 'папе', 'не', 'нравится', 'музыка.']),
#  ('__label__rus', ['Почему', 'он', 'хромает?']),
#  ('__label__tur', ['Yasak', 'meyve', 'her', 'zaman', 'en', 'tatlısıdır.']),
#  ('__label__eng', ['You', 'met', 'friends.']),
#  ('__label__tur', ['Onlar', "İsabela'nın", 'öldüğünü', 'söylüyorlar.']),
#  ('__label__rus', ['Переведено', 'с', 'французского.']),
#  ('__label__por', ['Quão', 'alto?']),
#  ('__label__ita',
#   ['Sabato',
#    'scorso',
#    'sono',
#    'andato',
#    'con',
#    'la',
#    'mia',
#    'famiglia',
#    'allo',
#    'zoo',
#    'per',
#    'vedere',
#    'i',
#    'panda.']),
#  ('__label__ita',
#   ['Noi', 'riusciamo', 'a', 'risolvere', 'facilmente', 'questo', 'problema.']),
#  ('__label__hun',
#   ['Fizetésének', 'nagy', 'része', 'elmegy', 'a', 'lakbérre.']),
#  ('__label__por',
#   ['A',
#    'Arábia',
#    'Saudita',
#    'não',
#    'salientou',
#    'o',
#    'número',
#    'de',
#    'mortos.',
#    'Anunciou',
#    'uma',
#    'investigação,',
#    'mas',
#    'não',
#    'divulgou',
#    'nenhum',
#    'resultado.']),
#  ...]

# %%
def count_words(data):
    '''
    Parameters:
    
    data is  list of [(label, words), (label, worlds), ......]
    list of tuples in the shape (string, [list of strings]) )
    
    Returns: 
    
    This function should return a dictionary containing the following:
    { 
    # label_counts (python dictionary): 
         {label:  no. of times the label appeared },
    # word_counts  (dictionary of dictionaries): 
         {label: {word: no. of times this word appeared with this label }},
    # label_total (int): 
        total number of labels. (size of train data),
    # word_total  (python dictionary) total number of words (from the entire corupus) of the particular label:
          {label: no.of words}
          
          }
    
    '''
    label_total = 0
    word_total = defaultdict(lambda: 0)
    label_counts = defaultdict(lambda: 0)
    word_counts = defaultdict(lambda: defaultdict(lambda: 0.0))

    for example in data:
        label, sentence = example
        ## FILL CODE
        label_counts[label]+=1.0
        label_total+=1.0
        
        for word in sentence:
            word_counts[label][word]+=1.0
            word_total[word]+=1.0
            
        
    
        
    return {'label_counts': label_counts, 
            'word_counts': word_counts, 
            'label_total': label_total, 
            'word_total': word_total}

# %%
def predict(sentence, mu, label_counts, word_counts, label_total, word_total):
    '''
     Parameters: 
        sentence (string): sentence to be classified
        mu (positive real number): Laplace Smoothing hyperparameter
        ** The other parameters introduced in the count_words function
    
    Returns:
    best_label (string): the label that has the highest score. 
    
    Implement the function to predict the best label for the given sentence using Naive Bayes algorithm 
    
    '''
    best_label = None
    best_score = float('-inf')

    for label in word_counts.keys():
        score = 0.0
        ## FILL CODE
        vocab_size=len(word_counts[label])
        for word in sentence:
            wc=word_counts[label][word]+mu
            tc=word_total[label]+mu*vocab_size
            score+=math.log(wc/tc)
        prior=label_counts[label]/sum(label_counts.values())
        score=score+math.log(prior)
        
        if best_score<score:
            best_label=label
            best_score=score
    return best_label

# %%
def compute_accuracy(valid_data, mu, counts):
    '''
    Parameters:
    valid_data (list of tuples): returned value of load_data function 
    mu (positive real): Laplace smoothing hyper-parameter
    counts (dictionary of dictionaries): return value of count_words_function
    
    Returns: 
    accuracy (float): the accuracy of the Naive Bayes classifier
    '''
    accuracy = 0.0
    for label, sentence in valid_data:
         ## FILL CODE
            if predict(sentence, mu, **counts)==label:
                accuracy+=1
                
            
            

    return accuracy/len(valid_data)

# %%
print("")
print("** Naive Bayes **")
print("")

mu = 1.0
train_data = load_data("train1.txt")
valid_data = load_data("valid1.txt")
counts = count_words(train_data)

print("Validation accuracy: %.3f" % compute_accuracy(valid_data, mu, counts))
print("")
# Out:
# ** Naive Bayes **
#
# Validation accuracy: 0.936
